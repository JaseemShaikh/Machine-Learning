# %% [markdown]
# #### Perform EDA and Perform customer segmentation on the following dataset:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl


from matplotlib import style
style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/segmentation data.csv')

# %%
data.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2000 non-null   int64
#  1   Sex              2000 non-null   int64
#  2   Marital status   2000 non-null   int64
#  3   Age              2000 non-null   int64
#  4   Education        2000 non-null   int64
#  5   Income           2000 non-null   int64
#  6   Occupation       2000 non-null   int64
#  7   Settlement size  2000 non-null   int64
# dtypes: int64(8)
# memory usage: 125.1 KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.distplot(data['Income'], hist = False)
plt.subplot(1,2,2)
sns.boxplot(y = data['Income'])
# Out:
# <Axes: ylabel='Income'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.countplot(x = data['Sex'], hue = data['Marital status'])
plt.subplot(1,2,2)
sns.countplot(x = data['Marital status'], hue = data['Sex'])
# Out:
# <Axes: xlabel='Marital status', ylabel='count'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x = data['Sex'],y = data['Age'])
plt.subplot(1,2,2)
sns.boxplot(x = data['Sex'],y = data['Age'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.countplot(x = data['Sex'], hue = data['Education'])
plt.subplot(1,2,2)
sns.countplot(x = data['Education'], hue = data['Sex'])
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x = data['Sex'], y = data['Education'])
plt.subplot(1,2,2)
sns.boxplot(x = data['Sex'], y = data['Education'])
# Out:
# <Axes: xlabel='Sex', ylabel='Education'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x = data['Sex'], y = data['Income'])
plt.subplot(1,2,2)
sns.boxplot(x = data['Sex'],y =  data['Income'])
# Out:
# <Axes: xlabel='Sex', ylabel='Income'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.countplot(x = data['Sex'], hue = data['Occupation'])
plt.subplot(1,2,2)
sns.countplot(x = data['Occupation'], hue = data['Sex'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.countplot(x = data['Sex'], hue = data['Settlement size'])
plt.subplot(1,2,2)
sns.countplot(x = data['Settlement size'], hue = data['Sex'])
# Out:
# <Axes: xlabel='Settlement size', ylabel='count'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x = data['Marital status'], y = data['Age'])
plt.subplot(1,2,2)
sns.boxplot(x = data['Marital status'], y = data['Age'])
# Out:
# <Axes: xlabel='Marital status', ylabel='Age'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.countplot(x = data['Marital status'], hue = data['Education'])
plt.subplot(1,2,2)
sns.countplot(x = data['Education'], hue = data['Marital status'])
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x = data['Marital status'],y= data['Income'])
plt.subplot(1,2,2)
sns.boxplot(x = data['Marital status'],y = data['Income'])
# Out:
# <Axes: xlabel='Marital status', ylabel='Income'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.countplot(x = data['Marital status'], hue = data['Occupation'])
plt.subplot(1,2,2)
sns.countplot(x = data['Occupation'], hue = data['Marital status'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize = (16,6), dpi = 200)
plt.subplot(1,2,1)
sns.countplot(x = data['Marital status'], hue = data['Settlement size'])
plt.subplot(1,2,2)
sns.countplot(x = data['Settlement size'], hue = data['Marital status'])
# Out:
# <Axes: xlabel='Settlement size', ylabel='count'>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data[['Age', 'Income']] = scaler.fit_transform(data[['Age', 'Income']])

# %%
data.drop(['ID'], axis = 1, inplace = True)

# %%
data
# Out:
#       Sex  Marital status       Age  Education    Income  Occupation  \
# 0       0               0  0.844828          2  0.324781           1
# 1       1               1  0.068966          1  0.420210           1
# 2       0               0  0.534483          1  0.195144           0
# 3       0               0  0.465517          1  0.496223           1
# 4       0               0  0.603448          1  0.413842           1
# ...   ...             ...       ...        ...       ...         ...
# 1995    1               0  0.500000          1  0.320595           0
# 1996    1               1  0.155172          1  0.299460           1
# 1997    0               0  0.224138          0  0.184871           0
# 1998    1               1  0.103448          1  0.227162           0
# 1999    0               0  0.120690          0  0.119123           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# ...

# %%
X = data[['Sex', 'Marital status','Age', 'Education', 'Income', 'Occupation', 'Settlement size']].values

# %%
X[:5]
# Out:
# array([[0.        , 0.        , 0.84482759, 2.        , 0.32478101,
#         1.        , 2.        ],
#        [1.        , 1.        , 0.06896552, 1.        , 0.42021043,
#         1.        , 2.        ],
#        [0.        , 0.        , 0.53448276, 1.        , 0.19514353,
#         0.        , 0.        ],
#        [0.        , 0.        , 0.46551724, 1.        , 0.49622348,
#         1.        , 1.        ],
#        [0.        , 0.        , 0.60344828, 1.        , 0.41384189,
#         1.        , 1.        ]])

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters = 5)
km.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
y_kmeans = km.predict(X)

# %%
y_kmeans
# Out:
# array([4, 1, 0, ..., 0, 3, 0], dtype=int32)

# %%
len(y_kmeans)
# Out:
# 2000

# %%
km.cluster_centers_
# Out:
# array([[2.34649123e-01, 9.21052632e-02, 3.04635511e-01, 7.47807018e-01,
#         2.20377067e-01, 2.56578947e-01, 3.72807018e-02],
#        [6.71597633e-01, 9.70414201e-01, 1.74760253e-01, 1.00000000e+00,
#         3.25043187e-01, 1.11242604e+00, 1.37573964e+00],
#        [4.31965443e-03, 1.66533454e-15, 3.25277426e-01, 6.71706263e-01,
#         3.86140977e-01, 1.26133909e+00, 1.52483801e+00],
#        [8.96103896e-01, 8.94248609e-01, 2.54814151e-01, 1.20037106e+00,
#         2.52477126e-01, 5.12059369e-01, 9.27643785e-03],
#        [4.65686275e-01, 6.91176471e-01, 6.45199459e-01, 2.15196078e+00,
#         4.76321622e-01, 1.31372549e+00, 1.39705882e+00]])

# %%
km.inertia_
# Out:
# 1575.7598154193765

# %%
wcss = []
for k in range(1,21):
    km = KMeans(n_clusters = k)
    km.fit(X)
    wcss.append(km.inertia_)

# %%
k = range(1,21)

plt.figure(figsize = (16,6), dpi = 200)
sns.lineplot(x = k, y = wcss)

plt.title('Elbow Method')
plt.xlabel('Number of clusters(K)')
plt.ylabel('WCSS')
plt.xticks(k)
plt.show()

# %%
2
# Out:
# 2
